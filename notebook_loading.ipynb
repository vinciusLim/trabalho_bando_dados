# %% [markdown]
# # Notebook Loading para Banco de Dados Postgres

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# Caminho do diretório onde as pastas de arquivos Parquet estão armazenados
parquet_directory_path = 'gold/'

# Dados de conexão com o PostgreSQL
user = 'vinicius'
password = '1234'
host = 'localhost'
port = '5432'
database = 'atividade_banco'

# Criar a string de conexão com PostgreSQL
connection_string = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}'

# Criar o motor de conexão
engine = create_engine(connection_string)

# Função para carregar os arquivos Parquet para o PostgreSQL
def carregar_arquivos_parquet(parquet_directory_path):
    # Listar todos os diretórios na pasta gold/
    diretorios = [d for d in os.listdir(parquet_directory_path) if os.path.isdir(os.path.join(parquet_directory_path, d))]

    if not diretorios:
        print(f'Nenhuma subpasta encontrada em {parquet_directory_path}.')
        return

    for diretorio in diretorios:
        # Caminho completo do diretório
        diretorio_path = os.path.join(parquet_directory_path, diretorio)

        # Listar todos os arquivos .parquet dentro da subpasta
        arquivos = [f for f in os.listdir(diretorio_path) if f.endswith('.parquet')]

        if not arquivos:
            print(f'Nenhum arquivo Parquet encontrado na pasta {diretorio_path}.')
            continue

        for arquivo in arquivos:
            # Caminho completo do arquivo Parquet
            parquet_file_path = os.path.join(diretorio_path, arquivo)
            
            # Ler o arquivo Parquet em um DataFrame
            try:
                df = pd.read_parquet(parquet_file_path, engine='pyarrow')
                print(f"Carregando dados de {arquivo}...")
                
                # Nome da tabela no PostgreSQL (usando o nome da subpasta como nome da tabela)
                table_name = diretorio  # Usamos o nome da subpasta como nome da tabela
                
                # Carregar os dados para o PostgreSQL
                try:
                    df.to_sql(table_name, engine, if_exists='replace', index=False)
                    print(f"Dados de {arquivo} carregados com sucesso na tabela {table_name}!")
                except Exception as e:
                    print(f"Ocorreu um erro ao carregar os dados de {arquivo}: {e}")
            
            except Exception as e:
                print(f"Ocorreu um erro ao ler o arquivo {arquivo}: {e}")

# Chama a função para carregar os arquivos Parquet
carregar_arquivos_parquet(parquet_directory_path)
# Out:
# Carregando dados de part-00000-922caf32-5066-4cc9-8957-ac991513266b-c000.snappy.parquet...
# Dados de part-00000-922caf32-5066-4cc9-8957-ac991513266b-c000.snappy.parquet carregados com sucesso na tabela dim_produto!
# Carregando dados de part-00001-922caf32-5066-4cc9-8957-ac991513266b-c000.snappy.parquet...
# Dados de part-00001-922caf32-5066-4cc9-8957-ac991513266b-c000.snappy.parquet carregados com sucesso na tabela dim_produto!
# Carregando dados de part-00007-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00007-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00005-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00005-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00008-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00008-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00010-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00010-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00011-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00011-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00000-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00000-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00004-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00004-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00003-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00003-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00001-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00001-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00006-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00006-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00009-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00009-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00002-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet...
# Dados de part-00002-48f87862-555d-42d1-95fc-659c2201dcc1-c000.snappy.parquet carregados com sucesso na tabela dim_geolocalizacao!
# Carregando dados de part-00000-66755c61-038c-4865-ac47-e974726d263a-c000.snappy.parquet...
# Dados de part-00000-66755c61-038c-4865-ac47-e974726d263a-c000.snappy.parquet carregados com sucesso na tabela dim_vendedor!
# Carregando dados de part-00007-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00007-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00005-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00005-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00006-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00006-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00009-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00009-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00002-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00002-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00001-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00001-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00008-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00008-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00011-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00011-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00003-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00003-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00004-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00004-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00000-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00000-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00010-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet...
# Dados de part-00010-4ac22a26-55fe-467d-b132-9f3741d9d345-c000.snappy.parquet carregados com sucesso na tabela fato_pedidos!
# Carregando dados de part-00001-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet...
# Dados de part-00001-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet carregados com sucesso na tabela dim_pagamento!
# Carregando dados de part-00000-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet...
# Dados de part-00000-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet carregados com sucesso na tabela dim_pagamento!
# Carregando dados de part-00003-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet...
# Dados de part-00003-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet carregados com sucesso na tabela dim_pagamento!
# Carregando dados de part-00002-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet...
# Dados de part-00002-a38fd0c8-f15d-4ae5-98a7-98aa24462828-c000.snappy.parquet carregados com sucesso na tabela dim_pagamento!
# Carregando dados de part-00000-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00000-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00003-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00003-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00001-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00001-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00005-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00005-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00006-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00006-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00004-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00004-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00002-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00002-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00007-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet...
# Dados de part-00007-3ff2694e-87b2-4f6d-91a7-5db8141af562-c000.snappy.parquet carregados com sucesso na tabela dim_cliente!
# Carregando dados de part-00002-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00002-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00005-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00005-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00000-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00000-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00004-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00004-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00008-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00008-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00006-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00006-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00003-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00003-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00009-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00009-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00001-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00001-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
# Carregando dados de part-00007-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet...
# Dados de part-00007-dda864d9-2049-4ae4-af3a-47a867319380-c000.snappy.parquet carregados com sucesso na tabela dim_avaliacao!
